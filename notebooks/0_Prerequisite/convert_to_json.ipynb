# %%
import tensorflow as tf
v1 = tf.Variable(tf.constant(1.0,shape=[1]),name="v1")
v2 = tf.Variable(tf.constant(2.0,shape=[2]),name="v2")
result = v1 + v2
saver=tf.train.Saver()
saver.export_meta_graph("/home/dev/save/model.ckpt.meda.jsono",as_text=True)
# Out:
# meta_info_def {
#   stripped_op_list {
#     op {
#       name: "Add"
#       input_arg {
#         name: "x"
#         type_attr: "T"
#       }
#       input_arg {
#         name: "y"
#         type_attr: "T"
#       }
#       output_arg {
#         name: "z"
#         type_attr: "T"
#       }
#       attr {
#         name: "T"
#         type: "type"
#         allowed_values {
#           list {
#             type: DT_HALF
#             type: DT_FLOAT
#             type: DT_DOUBLE
#             type: DT_UINT8
#             type: DT_INT8
#             type: DT_INT16
#             type: DT_INT32
#             type: DT_INT64
#             type: DT_COMPLEX64
#             type: DT_COMPLEX128
#             type: DT_STRING
#           }
#         }
#       }
#     }
#     op {
#       name: "Assign"
#       input_arg {
#         name: "ref"
#         type_attr: "T"
#         is_ref: true
#       }
#       input_arg {
#         name: "value"
#         type_attr: "T"
#       }
# ...
